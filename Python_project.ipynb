# %%
# Menu restaurant project

# %%
menu={
    "pizza":70,
    "burger":40,
    "role": 55,
    "briyani":100,
    "manchurian":50,
}

print("welcome to my restaurant")
print(" pizza:Rs=70\n burger:Rs=40\n role:Rs=55\n briyani:RS=100\n manchurian:RS=50")
order_total=0

item_1=input("enter the name of item you want to order=")
if item_1 in menu:
    order_total += menu[item_1]
    print(f" your tem {item_1} has been added to your order")

else:
    print(f"order item {item_1} is not avilable yet")

another_order=input("do you want to add another item? (yes/no) ")
if another_order == "yes":
    item_2=input("enter the name of second iteam=")
    if item_2 in menu:
        order_total += menu[item_2]
        print(f" item {item_2} has been added the order")
    else:
        print(f" order item {item_2} is not avilable!")
        
print(f"the total amount of items to pay is {order_total}")
# Out:
# welcome to my restaurant
#  pizza:Rs=70
#  burger:Rs=40
#  role:Rs=55
#  briyani:RS=100
#  manchurian:RS=50
# enter the name of item you want to order= pizza
#  your tem pizza has been added to your order
# do you want to add another item? (yes/no)  yes
# enter the name of second iteam= coffe
#  order item coffe is not avilable!
# the total amount of items to pay is 70
